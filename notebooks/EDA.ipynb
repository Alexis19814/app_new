# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\alexi\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 1)) (2.2.2)
# Collecting plotly_express (from -r requirements.txt (line 2))
#   Using cached plotly_express-0.4.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting streamlit (from -r requirements.txt (line 3))
#   Using cached streamlit-1.36.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\alexi\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 1)) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alexi\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alexi\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alexi\appdata\local\programs\python\python312\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2023.4)
# Collecting plotly>=4.1.0 (from plotly_express->-r requirements.txt (line 2))
#   Using cached plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting statsmodels>=0.9.0 (from plotly_express->-r requirements.txt (line 2))
#   Using cached statsmodels-0.14.2-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Collecting scipy>=0.18 (from plotly_express->-r requirements.txt (line 2))
#   Using cached scipy-1.14.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting patsy>=0.5 (from plotly_express->-r requirements.txt (line 2))
#   Using cached patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting altair<6,>=4.0 (from streamlit->-r requirements.txt (line 3))
#   Using cached altair-5.3.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit->-r requirements.txt (line 3))
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit->-r requirements.txt (line 3))
#   Using cached cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting click<9,>=7.0 (from streamlit->-r requirements.txt (line 3))
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=20 in c:\users\alexi\appdata\roaming\python\python312\site-packages (from streamlit->-r requirements.txt (line 3)) (24.1)
# Collecting pillow<11,>=7.1.0 (from streamlit->-r requirements.txt (line 3))
#   Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting protobuf<6,>=3.20 (from streamlit->-r requirements.txt (line 3))
#   Using cached protobuf-5.27.2-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting pyarrow>=7.0 (from streamlit->-r requirements.txt (line 3))
#   Using cached pyarrow-16.1.0-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Collecting requests<3,>=2.27 (from streamlit->-r requirements.txt (line 3))
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich<14,>=10.14.0 (from streamlit->-r requirements.txt (line 3))
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<9,>=8.1.0 (from streamlit->-r requirements.txt (line 3))
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit->-r requirements.txt (line 3))
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions<5,>=4.3.0 (from streamlit->-r requirements.txt (line 3))
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit->-r requirements.txt (line 3))
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->-r requirements.txt (line 3))
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\alexi\appdata\roaming\python\python312\site-packages (from streamlit->-r requirements.txt (line 3)) (6.4.1)
# Collecting watchdog<5,>=2.1.5 (from streamlit->-r requirements.txt (line 3))
#   Using cached watchdog-4.0.1-py3-none-win_amd64.whl.metadata (37 kB)
# Collecting jinja2 (from altair<6,>=4.0->streamlit->-r requirements.txt (line 3))
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit->-r requirements.txt (line 3))
#   Using cached jsonschema-4.22.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting toolz (from altair<6,>=4.0->streamlit->-r requirements.txt (line 3))
#   Using cached toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: colorama in c:\users\alexi\appdata\roaming\python\python312\site-packages (from click<9,>=7.0->streamlit->-r requirements.txt (line 3)) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 3))
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: six in c:\users\alexi\appdata\local\programs\python\python312\lib\site-packages (from patsy>=0.5->plotly_express->-r requirements.txt (line 2)) (1.16.0)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.27->streamlit->-r requirements.txt (line 3))
#   Using cached charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.27->streamlit->-r requirements.txt (line 3))
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.27->streamlit->-r requirements.txt (line 3))
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.27->streamlit->-r requirements.txt (line 3))
#   Downloading certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 3))
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alexi\appdata\roaming\python\python312\site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 3)) (2.18.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 3))
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->altair<6,>=4.0->streamlit->-r requirements.txt (line 3))
#   Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Collecting attrs>=22.2.0 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 3))
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 3))
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 3))
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 3))
#   Using cached rpds_py-0.18.1-cp312-none-win_amd64.whl.metadata (4.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r requirements.txt (line 3))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Using cached streamlit-1.36.0-py2.py3-none-any.whl (8.6 MB)
# Using cached altair-5.3.0-py3-none-any.whl (857 kB)
# Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Using cached cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Using cached patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached plotly-5.22.0-py3-none-any.whl (16.4 MB)
# Using cached protobuf-5.27.2-cp310-abi3-win_amd64.whl (426 kB)
# Using cached pyarrow-16.1.0-cp312-cp312-win_amd64.whl (25.8 MB)
# Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Using cached scipy-1.14.0-cp312-cp312-win_amd64.whl (44.5 MB)
# Using cached statsmodels-0.14.2-cp312-cp312-win_amd64.whl (9.8 MB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached watchdog-4.0.1-py3-none-win_amd64.whl (83 kB)
# Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#    ---------------------------------------- 0.0/163.0 kB ? eta -:--:--
#    -------------------- ------------------- 81.9/163.0 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 163.0/163.0 kB 3.2 MB/s eta 0:00:00
# Using cached charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached jsonschema-4.22.0-py3-none-any.whl (88 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Using cached toolz-0.12.1-py3-none-any.whl (56 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached rpds_py-0.18.1-cp312-none-win_amd64.whl (209 kB)
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, urllib3, typing-extensions, toolz, toml, tenacity, smmap, scipy, rpds-py, pyarrow, protobuf, pillow, patsy, mdurl, MarkupSafe, idna, click, charset-normalizer, certifi, cachetools, blinker, attrs, requests, referencing, plotly, markdown-it-py, jinja2, gitdb, statsmodels, rich, pydeck, jsonschema-specifications, gitpython, plotly_express, jsonschema, altair, streamlit
# Successfully installed MarkupSafe-2.1.5 altair-5.3.0 attrs-23.2.0 blinker-1.8.2 cachetools-5.3.3 certifi-2024.7.4 charset-normalizer-3.3.2 click-8.1.7 gitdb-4.0.11 gitpython-3.1.43 idna-3.7 jinja2-3.1.4 jsonschema-4.22.0 jsonschema-specifications-2023.12.1 markdown-it-py-3.0.0 mdurl-0.1.2 patsy-0.5.6 pillow-10.4.0 plotly-5.22.0 plotly_express-0.4.1 protobuf-5.27.2 pyarrow-16.1.0 pydeck-0.9.1 referencing-0.35.1 requests-2.32.3 rich-13.7.1 rpds-py-0.18.1 scipy-1.14.0 smmap-5.0.1 statsmodels-0.14.2 streamlit-1.36.0 tenacity-8.5.0 toml-0.10.2 toolz-0.12.1 typing-extensions-4.12.2 urllib3-2.2.2 watchdog-4.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import plotly.express as px

car_data = pd.read_csv('vehicles_us.csv') # leer los datos
fig = px.histogram(car_data, x="odometer") # crear un histograma
fig.show() # crear gráfico de dispersión
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 6
#       4 car_data = pd.read_csv('vehicles_us.csv') # leer los datos
#       5 fig = px.histogram(car_data, x="odometer") # crear un histograma
# ----> 6 fig.show() # crear gráfico de dispersión
#
# File c:\Users\ALEXI\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)
#    3406 None
#    3407 """
#    3408 import plotly.io as pio
# -> 3410 return pio.show(self, *args, **kwargs)
#
# File c:\Users\ALEXI\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
